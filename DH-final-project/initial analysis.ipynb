# %%
import pandas as pd
import nltk
import numpy as np
import re

# %%
genius_data = pd.read_csv('genius_bts_discography_rough (1).csv')
genius_data.drop(['Unnamed: 0', 'Written By', 'Produced By', 'Description'], axis=1, inplace=True) #drop columns irrelevant for this analysis

##add columns for most common latin word, most common non-latin word
genius_data.insert(4, "Most Common LATIN Word", [str(np.nan) for i in range(len(genius_data))])
genius_data.insert(4, "Most Common NON-Latin Word", [str(np.nan) for i in range(len(genius_data))])
genius_data.insert(4, "Most Common Word", [str(np.nan) for i in range(len(genius_data))])

genius_data.head()
# Out:
#                         Song                Album     Release Date  \
# 0                   Dynamite  Dynamite (Extended)  August 21, 2020
# 1    Dynamite (Instrumental)  Dynamite (Extended)  August 21, 2020
# 2  Dynamite (Acoustic Remix)  Dynamite (Extended)  August 24, 2020
# 3       Dynamite (EDM Remix)  Dynamite (Extended)  August 24, 2020
# 4  Dynamite (Tropical Remix)    Dynamite (Deluxe)  August 28, 2020
#
#                                               Lyrics Most Common Word  \
# 0  \n\n[Intro: Jungkook]\n'Cause I, I, I'm in the...              nan
# 1                             \n\n[Instrumental]\n\n              nan
# 2  \n\n[Intro: Jungkook]\n'Cause I, I, I'm in the...              nan
# 3  \n\n[Intro: Jungkook]\n'Cause I, I, I'm in the...              nan
# 4  \n\n[Intro: Jungkook]\n'Cause I, I, I'm in the...              nan
#
#   Most Common NON-Latin Word Most Common LATIN Word  \
# 0                        nan                    nan
# 1                        nan                    nan
# 2                        nan                    nan
# 3                        nan                    nan
# 4                        nan                    nan
#
#                                                  URL
# 0             https://genius.com/Bts-dynamite-lyrics
# 1  https://genius.com/Bts-dynamite-instrumental-l...
# 2  https://genius.com/Bts-dynamite-acoustic-remix...
# 3   https://genius.com/Bts-dynamite-edm-remix-lyrics
# 4  https://genius.com/Bts-dynamite-tropical-remix...

# %%
#tokenize + clean initial lyrics string
def tokenize_lyrics(original_string):
    #split lyrics on lines and remove everything that isnt lyrics (blank lines, verse headers)
    lyrics_lines = original_string.split("\n")
    lyrics_only_lines = " ".join([x for x in lyrics_lines if x != '' and x[0] != '[']) 
    lyrics_only_lines = lyrics_only_lines.replace('\u2005', ' ').replace('\u205f', ' ') #take out all random weirdly formatted spaces

    #lowercase words and split on spaces
    tokenized_lyrics = lyrics_only_lines.lower()
    #remove punctuation except - and ', since they are part of words
    tokenized_lyrics = re.sub(r'[!?.()"":;/,]', '', tokenized_lyrics) 
    tokenized_lyrics = tokenized_lyrics.split(" ")

    ##not that we are NOT removing stop words right now######





    return tokenized_lyrics

# %%
##split tokenized lyrics by language
#note that latin words might be in spanish, etc.
#non-latin words could be in korean, japanese, etc.
def split_language(tokenized_lyrics):
    latin_words = []
    non_latin_words = []
    for i in tokenized_lyrics:
        result = re.search(r'([a-z])', i)
        if result == None:
            non_latin_words.append(i)

        else:
            latin_words.append(i)

    return non_latin_words, latin_words

# %%
##function to get momst common word in list
def get_most_common(words_list):
    try:
        return pd.Series(words_list).value_counts().index[0]
    except: 
        return np.nan

# %%
for i, row in genius_data.iterrows():
    this_original_lyrics = row["Lyrics"]

    this_tokenized_lyrics = tokenize_lyrics(this_original_lyrics)

    this_non_latin = split_language(this_tokenized_lyrics)[0]
    this_latin = split_language(this_tokenized_lyrics)[1]

    this_most_common_non_latin = get_most_common(this_non_latin)
    this_most_common_latin = get_most_common(this_latin)
    this_most_common = get_most_common(this_tokenized_lyrics)

    print(row["Song"] + ": ", this_most_common, "| ", this_most_common_non_latin, this_most_common_latin)
    #write into data frame
    genius_data.at[i, "Most Common NON-Latin Word"] = this_most_common_non_latin
    genius_data.at[i, "Most Common LATIN Word"] = this_most_common_latin
    genius_data.at[i, "Most Common Word"] = this_most_common
# Out:
# Dynamite:  the |  nan the
# Dynamite (Instrumental):   |   nan
# Dynamite (Acoustic Remix):  the |  nan the
# Dynamite (EDM Remix):  the |  nan the
# Dynamite (Tropical Remix):  the |  nan the
# Dynamite (Poolside Remix):  the |  nan the
# Dynamite:  the |  nan the
# Dynamite (Instrumental):   |   nan
# Dynamite (Acoustic Remix):  the |  nan the
# Dynamite (EDM Remix):  the |  nan the
# INTRO: Calling:  心惹かれて |  君の全てに gold
# Stay Gold:  gold |  夢の中でも gold
# Boy With Luv - Japanese ver.:  my |  ウォーウォウォウォウォ my
# Make It Right - Japanese ver.:  大丈夫です |  大丈夫です 赤ちゃんi
# Dionysus - Japanese ver.:  it |  さあ、酔え酔え酔え　今 it
# IDOL - Japanese ver.:  i |  オルッス i
# Airplane pt.2 - Japanese ver.:  i |   i
# FAKE LOVE - Japanese ver.:  love |  君の為なら love
# Black Swan - Japanese ver.:  yeah |  海が光飲み込み yeah
# ON - Japanese ver.:  oh |  持って来い oh
# Lights:  light |  離れていても届いてる light
# Your eyes tell:  so |  どこにも行かないように so
# OUTRO: The Journey:   |   nan
# Intro: Persona:  i |  나 i
# 작은 것들을 위한 시 (Boy With Luv):  my |  워워워워워 my
# Make It Right:  right |  날 right
# Jamais Vu:  remedy |  날 remedy
# Dionysus:  마셔 |  마셔 it
# Interlude: Shadow:  i |  네가 i
# Black Swan:  yeah |  내 yeah
# Filter:  your |  날 your
# 시차 (My Time):  ooh |  같아 ooh
# Louder than bombs:  oh |  우리가 oh
# ON:  pain |  가져와 the
# 욱 (UGH!):  욱 |  욱 yeah
# 00:00 (Zero O’Clock):  be |  숨을 and
# Inner Child:  change |  거야 change
# 친구 (Friends):  ayy |  오래 ayy
# Moon:  네 |  네 ooh
# Respect:  respect |  나도 respect
# We Are Bulletproof : The Eternal:  we |  우린 we
# Outro: Ego:  ego |  길로 ego
# Intro: Persona:  i |  나 i
# 작은 것들을 위한 시 (Boy With Luv):  my |  워워워워워 my
# Make It Right:  right |  날 right
# Jamais Vu:  remedy |  날 remedy
# Dionysus:  마셔 |  마셔 it
# Interlude: Shadow:  i |  네가 i
# Black Swan:  yeah |  내 yeah
# Filter:  your |  날 your
# 시차 (My Time):  ooh |  같아 ooh
# Louder than bombs:  oh |  우리가 oh
# ON:  pain |  가져와 the
# 욱 (UGH!):  욱 |  욱 yeah
# 00:00 (Zero O’Clock):  be |  숨을 and
# Inner Child:  change |  거야 change
# 친구 (Friends):  ayy |  오래 ayy
# Moon:  네 |  네 ooh
# Respect:  respect |  나도 respect
# We Are Bulletproof : The Eternal:  we |  우린 we
# Outro: Ego:  ego |  길로 ego
# ON (Remix):  i'm |  내 i'm
# Lights:  light |  離れていても届いてる light
# Boy With Luv - Japanese ver.:  my |  ウォーウォウォウォウォ my
# IDOL - Japanese ver.:  i |  オルッス i
# Heartbeat:  널 |  널 me
# Dream Glow:  hey |  에 hey
# A Brand New Day:  be |  두려움 be
# All Night:  all |  더 all
# Captain (Namjun Theme):   |   nan
# Cake Waltz (Jimin Theme):   |   nan
# Shine (Yunki Theme):   |   nan
# Not Alone (Jeongguk Theme):   |   nan
# Friends (Hoseok Theme):   |   nan
# Wish (Seok Jin Theme):   |   nan
# Flying (Taehyung Theme):   |   nan
# LaLaLa:  니 |  니 oh
# You Are Here:  니가 |  니가 nan
# You Are Here (Instrumental):   |   nan
# Intro: Persona:  i |  나 i
# 작은 것들을 위한 시 (Boy With Luv):  my |  워워워워워 my
# 소우주 (Mikrokosmos):  na |  빛나는 na
# Make It Right:  right |  날 right
# HOME:  your |  다 your
# Jamais Vu:  remedy |  날 remedy
# Dionysus:  마셔 |  마셔 it
# FAKE LOVE - Japanese ver.:  love |  君の為なら love
# Airplane pt.2 - Japanese ver.:  i |   i
# IDOL (Stadium Remix):  i |  얼쑤 i
# FAKE LOVE - Japanese ver. (Remix):  love |  君の為なら love
# Euphoria:  yeah |  꿈을 yeah
# Trivia 起: Just Dance:  wanna |  너와 wanna
# Serendipity (Full Length Edition):  me |  그냥 me
# DNA:  dna |  아니니까 dna
# 보조개 (​Dimple):  anyway |  그 ah
# Trivia 承: Love:  i |  사람 i
# Her:  her |  내 her
# Singularity:    |    tell
# FAKE LOVE:  love |  널 love
# 전하지 못한 진심 (The Truth Untold):  you |  이 you
# Trivia 轉: Seesaw:  up |  시소게임 up
# Tear:  you're |  그 my
# Epiphany:  love |  내 love
# I'm Fine:  fine |  괜찮아 fine
# IDOL:  i |  얼쑤 i
# Answer: Love Myself:  나 |  나 myself
# Magic Shop:  show |  너의 show
# Best of Me:  me |  넌 me
# Airplane pt.2:  i |  구름 i
# 고민보다 Go (Go Go):  yolo |  탕진잼 yolo
# Anpanman:  anpanman |  몰래 anpanman
# MIC Drop:  you |  발 you
# DNA (Pedal 2 LA Mix):  la |  계속 la
# FAKE LOVE (Rocking Vibe Mix):  love |  널 love
# MIC Drop [Steve Aoki Remix] (Full Length Edition):  you |  조심 you
# IDOL (Remix):  i |  얼쑤 i
# Love Yourself: 結 Answer Notes:  i |  22 i
# 화양연화 The Notes Pt. 3:  the |  3 the
# Intro: Singularity:  그 |  그 oh
# FAKE LOVE:  love |  널 love
# 전하지 못한 진심 (The Truth Untold):  you |  이 you
# 134340:  난 |  난 ay
# 낙원 (Paradise):  괜찮아 |  괜찮아 my
# Love Maze:  my-y-y |  절대 my-y-y
# Magic Shop:  show |  너의 show
# Airplane pt.2:  i |  구름 i
# Anpanman:  anpanman |  몰래 anpanman
# So What:  oh |  고민 oh
# Outro: Tear:  my |  그 my
# 화양연화 The Notes Pt. 2:  my |  22 my
# Love Yourself: 轉 Tear Notes:  i |  22 i
# INTRO : Ringwanderung:  me |  波のようにいたけど me
# Best of Me (Japanese Ver.):  me |  いつでも me
# 血、汗、淚 (Blood, Sweat & Tears) (Japanese Ver.):  マニ |  マニ oh
# DNA (Japanese Ver.):  la |  全ては偶然じゃないから la
# Not Today (Japanese Ver.):  not |  銃！照準！発射！ not
# MIC Drop (Japanese Version):  you |  そのマイク、マイク注意 you
# Don't Leave Me:  例えどんな |  例えどんな me
# Go Go (Japanese Ver.):  yolo |  탕진잼 yolo
# Crystal Snow:  crystal |  もう一度 crystal
# Spring Day (Japanese Ver.):  会いたい… |  会いたい… friend
# Let Go:  let |  今君の手を let
# OUTRO : Crack:  go |  nan go
# Euphoria:  yeah |  꿈을 yeah
# MIC Drop (Japanese Version):  you |  そのマイク、マイク注意 you
# DNA (Japanese Ver.):  la |  全ては偶然じゃないから la
# Crystal Snow:  crystal |  もう一度 crystal
# Intro: Serendipity (세렌디피티):  me |  그냥 me
# DNA:  dna |  아니니까 dna
# Best of Me:  me |  넌 me
# 보조개 (​Dimple):  anyway |  그 ah
# Pied Piper:  oh-oh-oh-oh-oh |  거야 oh-oh-oh-oh-oh
# SKIT: Billboard Music Awards Speech:  and |  방탄소년단 the
# MIC Drop:  you |  발 you
# 고민보다 Go (Go Go):  yolo |  탕진잼 yolo
# Outro: Her:  her |  내 her
# Skit: 망설임과 두려움 (Hesitation and Fear):  i |  - i
# 바다 (Sea):  missing |  nan missing
# 화양연화 The Notes Pt. 1:  the |  13 the
# Love Yourself: 承 Her Notes:  the |  22 the
# Love Yourself: 承 Her Thanks To:  you |  & you
# 血、汗、淚 (Blood, Sweat & Tears) (Japanese Ver.):  マニ |  マニ oh
# Not Today (Japanese Ver.):  not |  銃！照準！発射！ not
# Spring Day (Japanese Ver.):  会いたい… |  会いたい… friend
# 血、汗、涙 (Blood Sweat & Tears) (Japanese Version):  マニ |  マニ te
# Not Today (Japanese Version):  not |   not
# Intro: Boy Meets Evil:  too |  내 too
# 피 땀 눈물 (Blood Sweat & Tears):  많이 |  많이 to
# BEGIN:  me |  나 me
# LIE:  나를 |  나를 a
# STIGMA:  더 |  더 i'm
# FIRST LOVE:  그때 |  그때 piano
# REFLECTION:  i |  나는 i
# MAMA:  mama |  돼 mama
# AWAKE:  awake |  싶어 awake
# Lost:  way |  길을 way
# BTS Cypher 4:  i |  내 i
# Am I Wrong:  why |  미쳤어 why
# 21세기 소녀 (21st Century Girl):  you |  넌 you
# 둘! 셋! (그래도 좋은 날이 더 많기를) [2! 3! (Still Wishing For More Good Days)]:  둘 |  둘 you
# 봄날 (Spring Day):  보고 |  보고 friend
# Not Today:  not |   not
# Outro: Wings:  la |  난 la
# A Supplementary Story : You Never Walk Alone:  수 |  수 walk
# You Never Walk Alone Thanks To:  you |  | you
# You Never Walk Alone [Photobook] (Right Ver.):  images |  nan images
# You Never Walk Alone [Photobook] (Left Ver.):  images |  nan images
# No More Dream (Japanese Ver.):   |   go
# BOY IN LUV (Japanese Ver.):  you |   you
# Danger (Japanese Ver.):  i |  惑わせるなもう！ i
# 進撃の防弾 (The Rise of Bangtan) (Japanese Ver.):  fire |  防弾少年団の様 fire
# Miss Right (Japanese Ver.):  you |   you
# FOR YOU:  no |  キラキラ舞う no
# ホルモン戦争 War of Hormone (Japanese Ver.):  la |   la
# I NEED U (Japanese Ver.):  i |  & you
# DOPE -超ヤベー!- (Japanese Ver.):  i |   i
# RUN (Japanese Ver.):  run |  また run
# FIRE (Japanese Ver.):  la |  全部灰にしな la
# Save Me (Japanese Ver.):  me |  その手を出して me
# EPILOGUE : Young Forever (Japanese Ver.):  forever |   forever
# Intro: Boy Meets Evil:  too |  내 too
# 피 땀 눈물 (Blood Sweat & Tears):  많이 |  많이 to
# BEGIN:  me |  나 me
# LIE:  나를 |  나를 a
# STIGMA:  더 |  더 i'm
# FIRST LOVE:  그때 |  그때 piano
# REFLECTION:  i |  나는 i
# MAMA:  mama |  돼 mama
# AWAKE:  awake |  싶어 awake
# Lost:  way |  길을 way
# BTS Cypher 4:  i |  내 i
# Am I Wrong:  why |  미쳤어 why
# 21세기 소녀 (21st Century Girl):  you |  넌 you
# 둘! 셋! (그래도 좋은 날이 더 많기를) [2! 3! (Still Wishing For More Good Days)]:  둘 |  둘 you
# Interlude: Wings:  fly |  난 fly
# Introduction: Youth:  nai |  nan nai
# RUN (Japanese Ver.):  run |  また run
# FIRE (Japanese Ver.):  la |  全部灰にしな la
# DOPE -超ヤベー!- (Japanese Ver.):  i |   i
# Good Day:  be |  当然 be
# Save Me (Japanese Ver.):  me |  その手を出して me
# フンタン少年団 (Boyz With Fun) (Japanese Ver.):  wussup |   wussup
# ペップセ (Peppuse) (Silver Spoon) (Japanese Ver.):  you |  ā you
# Wishing On a Star:  a |  思うほどきっと届く a
# Butterfly (Japanese Ver.):  butterfly |   butterfly
# FOR YOU:  no |  キラキラ舞う no
# I NEED U (Japanese Ver.):  i |  & you
# EPILOGUE : Young Forever (Japanese Ver.):  forever |   forever
# Intro: 화양연화 (The Most Beautiful Moment In Life):  다시 |  다시 life
# I NEED U:  i |  왜 i
# 잡아줘 (Hold Me Tight):  trust |  날 me
# 고엽 (Autumn Leaves):  never |  내 never
# Butterfly (Prologue Mix):  butterfly |  겁나 butterfly
# RUN:  run |  난 run
# Ma City:  la |  그래 la
# 뱁새 (Silver Spoon/Baepsae):  아 |  아 me
# 쩔어 (DOPE):  쩔어 |  쩔어 i
# FIRE (불타오르네):  la |  다 la
# Save ME:  me |  손을 me
# EPILOGUE : Young Forever:  forever |  난 forever
# Converse High:  컨버스하이 |  컨버스하이 really
# 이사 (Moving On):  이사 |  이사 on
# Whalien 52:  lonely |  수 lonely
# Butterfly:  겁나 |  겁나 butterfly
# House of Cards (Full Length Edition):  더 |  더 no
# Love Is Not Over (Full Length Edition):  것 |  것 over
# I NEED U (Urban Mix):  i |  왜 i
# I NEED U (Remix):  i |  왜 i
# RUN (Ballad Mix):  run |  난 run
# RUN (Alternative Mix):  run |  난 run
# Butterfly (Alternative Mix):  겁나 |  겁나 butterfly
# RUN (Japanese Ver.):  run |  また run
# Butterfly (Japanese Ver.):  butterfly |   butterfly
# Good Day:  be |  当然 be
# I NEED U (Japanese Ver.):  i |  & you
# DOPE -超ヤベー!- (Japanese Ver.):  i |   i
# フンタン少年団 (Boyz With Fun) (Japanese Ver.):  wussup |   wussup
# INTRO : Never Mind:  mind |  것 mind
# RUN:  run |  난 run
# Butterfly:  겁나 |  겁나 butterfly
# Whalien 52:  lonely |  수 lonely
# Ma City:  la |  그래 la
# 뱁새 (Silver Spoon/Baepsae):  아 |  아 me
# SKIT : One night in a strange city:  랩몬스터 |  랩몬스터 a
# 고엽 (Autumn Leaves):  never |  내 never
# OUTRO : House Of Cards:  no |  우린 no
# FOR YOU:  no |  キラキラ舞う no
# ホルモン戦争 War of Hormone (Japanese Ver.):  la |   la
# Let Me Know (Japanese Ver.):  know |  何でもいいから know
# Intro: 화양연화 (The Most Beautiful Moment In Life):  다시 |  다시 life
# I NEED U:  i |  왜 i
# 잡아줘 (Hold Me Tight):  trust |  날 me
# SKIT : Expectation!:  translation |  nan translation
# 쩔어 (DOPE):  쩔어 |  쩔어 i
# 흥탄소년단 (Boyz with Fun):  흥 |  흥 wo
# Converse High:  컨버스하이 |  컨버스하이 really
# 이사 (Moving On):  이사 |  이사 on
# Outro : Love is Not Over:  over |  것 over
# INTRO:  wake |  nan wake
# THE STARS:  night |  高鳴る night
# JUMP (Japanese Ver.):  let's |   let's
# Danger (Japanese Ver.):  i |  惑わせるなもう！ i
# BOY IN LUV (Japanese Ver.):  you |   you
# Just One Day (Japanese Ver. Extended):  one |  君と2人いれるなら one
# いいね! (I Like It!) (Japanese Ver.):  wanna |  離れてから君は wanna
# I Like It Pt.2 ~In That Place~ (いいね！Pt.2～あの場所で～ ):  you |   you
# No More Dream (Japanese Ver.):   |   go
# N.O (Japanese Ver.):  we |   we
# Wake Up:  up |  目を覚まして、ほら up
# OUTRO:  gotta |  nan gotta
# 進撃の防弾 (The Rise of Bangtan) (Japanese Ver.):  fire |  防弾少年団の様 fire
# 좋아요 Pt. 2 (I Like it Pt. 2):  girl |  넌 girl
# No More Dream:  la |  니 la
# N.O:  roll |  게 we
# 진격의 방탄 (Attack on Bangtan/The Rise of Bangtan):  누구 |  누구 higher
# Boy in Luv (상남자):  what |  내 what
# 하루만 (Just One Day):  하루만 |  하루만 do
# Danger:  너 |  너 uh
# 호르몬 전쟁 (War of Hormone):  la |  최고 la
# 힙합성애자 (Hip Hop Lover/Phile):  hop |  내 hip
# Let Me Know:  know |  말해줘 know
# Boy in Luv (Chinese Ver.):   |   you
# Danger (Japanese Ver.):  i |  惑わせるなもう！ i
# Miss Right (Japanese Ver.):  you |   you
# 進撃の防弾 (The Rise of Bangtan) (Japanese Ver.):  fire |  防弾少年団の様 fire
# Intro: What am I to You:  you |  난 you
# Danger:  너 |  너 uh
# 호르몬 전쟁 (War of Hormone):  la |  최고 la
# 힙합성애자 (Hip Hop Lover/Phile):  hop |  내 hip
# Let Me Know:  know |  말해줘 know
# Rain:  missing |  nan missing
# BTS Cypher PT.3 : KILLER:  내 |  내 i
# Interlude: 뭐해 (What Are You Doing Now):  뭐해 |  뭐해 interlude
# 핸드폰 좀 꺼줄래 (Could You Turn Off Your Cell Phone?):  좀 |  좀 tap
# 이불킥 (Blanket Kick/Embarrassed):  예뻐 |  예뻐 woo
# 24/7=Heaven:  sunday |  난 sunday
# 여기 봐 (Look Here):  봐 |  봐 me
# 2학년 (Second Grade/So 4 More):  it |  새 it
# Outro : 그게 말이 돼? (Do You Think It Makes Sense?):  missing |  nan missing
# Can You Turn Off Your Phone:  좀 |  좀 jungkook
# BOY IN LUV (Japanese Ver.):  you |   you
# N.O (Japanese Ver.):  we |   we
# Just One Day (Japanese Ver.):  one |  2 one
# No More Dream (Japanese Ver.):   |   go
# いいね! (I Like It!) (Japanese Ver.):  wanna |  離れてから君は wanna
# 進撃の防弾 (The Rise of Bangtan) (Japanese Ver.):  fire |  防弾少年団の様 fire
# Miss Right:  right |  너의 right
# 좋아요 (I Like It) (Slow Jam Remix):  wanna |  넌 be
# Intro: Skool Luv Affair:  style |  좀 style
# Boy in Luv (상남자):  what |  내 what
# 어디에서 왔는지 (Where Did You Come From):  궁금해 |  궁금해 oh
# 하루만 (Just One Day):  하루만 |  하루만 do
# Tomorrow:  마 |  마 tomorrow
# BTS Cypher PT. 2 : Triptych:  때문에 |  때문에 i
# 등골브레이커 (Spine Breaker):  la |  넌 la
# JUMP:  jump |  손을 jump
# Outro: Propose:  you |  웃어주는 you
# Intro: Skool Luv Affair:  style |  좀 style
# Boy in Luv (상남자):  what |  내 what
# Skit: Soulmate:  pdogg |  아 j-hope
# 어디에서 왔는지 (Where Did You Come From):  궁금해 |  궁금해 oh
# 하루만 (Just One Day):  하루만 |  하루만 do
# Tomorrow:  마 |  마 tomorrow
# BTS Cypher PT. 2 : Triptych:  때문에 |  때문에 i
# 등골브레이커 (Spine Breaker):  la |  넌 la
# JUMP:  jump |  손을 jump
# Outro: Propose:  you |  웃어주는 you
# Intro: O!RUL8,2?:  you |  왜 you
# N.O:  roll |  게 we
# We On:  my |  보여줄게 my
# Skit: R U Happy Now?:  monster |  진짜 rap
# If I Ruled the World:  the |  1 the
# Coffee:  baby |  그대는 baby
# BTS Cypher Pt.1:  난 |  난 the
# 진격의 방탄 (Attack on Bangtan/The Rise of Bangtan):  누구 |  누구 higher
# 팔도강산 Paldogangsan (Satoori Rap):  what |  전라도 what
# OUTRO: LUV IN SKOOL:  oh |  같아 oh
# BTS Soundcloud Tracks and Official Features Guide:  rm |  4 rm
# 마지막 (The Last):  내 |  내 uh
# 가을 우체국 앞에서 (Autumn Outside the Post Office) (Cover):  in |  저 the
# 이런 엔딩 by JK of BTS (Ending scene | IU cover):  다 |  다 nan
# 그때 헤어지면 돼 (Only Then) (Cover):  we |  그때 we
# So Far Away (Jin & Jungkook Cover):  away |  꿈이 away
# Fools (COVER):  fools |  nan fools
# Beautiful (Cover):  with |  해 me
# Perfect Christmas - Special Artists Sketch:  you |  난 you
# So 4 More:  i |  이 i
# 약속 (Promise):  oh |  수 oh
# Airplane:  때 |  때 airplane
# 10,000 Hours (Cover):  you |  10000 you
# Speech at the United Nations 2018 General Assembly:  i |  nan i
# Seesaw X I NEED U REMIX:  girl |  왜 girl
# 봄날 (Spring Day Brit Rock Remix for 가요대축제):  you |  보고 you
# 안아줘 (Hug Me) - Cover:  you |  내 you
# 흔한 연습생의 크리스마스 (A Typical Trainee's Christmas):  to |  안 to
# I Believe:  believe |  내가 believe
# Adult Child (어른아이):  a |  된 a
# We Don't Talk Anymore, Pt. 2:  we |  nan we
# P.O.P (Piece of Peace) Pt.1:  i |  누군가에게 i
# Daydream (백일몽):  daydream |  거야 daydream
# Where U At:  at |  어디로 where
# Lost Stars (Cover):  the |  nan the
# Agust D:  to |  보내는 to
# Decalcomania (Demo):  i |  nan i
# Born Singer:  i'm |   i'm
# 2U:  to |  nan to
# Life:  we |  걸까 we
# Christmas Day:  you |  오늘도 you
# 풍경 (Scenery):  wonder |  그 wonder
# Rush:  the |  서둘러 the
# Monster:  c'mon |  느낀다면 c'mon
# 이 밤 (This Night):  눈을 |  눈을 nan
# 네시 (4 O'CLOCK):  you |  걸음씩 you
# So Far Away:  away |  있다면 away
# Tony Montana:  i |  ㅎ i
# 140503 새벽에 (140503 At Dawn):  척 |  척 nan
# 치리사일사팔 (724148):  그 |  그 ok
# Skit:  슈가 |  슈가 nan
# Give It To Me:  me |  뭐든 me
# Intro; Dt sugA:  to |  쉴 to
# Blue Side (Outro):  blue |  내 blue
# Unpack Your Bags:  my |   my
# 땡 (Ddaeng):  땡 |  땡 you
# 싸이하누월 (It Doesn’t Matter) Mix Final:  click |  상관없어 click
# Dream Money:  i |  삶을 i
# Winter Bear:  good |  nan good
# 알아요 (I Know):  you |  곁에 you
# 1 VERSE:  i |  내 i
# God Rap:  i |  난 i
# 농담 (Joke):  it |  넌 it
# 버려 (Throw Away):  it |  100 it
# Awakening (각성/覺醒):  i |  내 i
# Do You:  you |  많지 you
# Voice (목소리):  수 |  수 you
# Base Line:  base |  내 base
# Just Think About It:  thinking |  コレは超ヤバイ thinking
# 항상 (HANGSANG):  my |  항상 my
# Like A Star:  like |  어중간한 like
# We Are Bulletproof Pt. 1 (4 BEGINS Ruff):  we |  내 we
# Hope World:  my |  나만의 my
# Rap Monster:  the |  내 the
# 표류 (Adrift):  in |  난 in
# Always:  i |  날 i
# Too Much:  too |  내가 too
# Monterlude:  oh |  nan oh
# Something:  could |  돼 could
# P.D.D (Please Don't Die):  me |  나의 me
# Favorite Girl:  favorite |   favorite
# Still With You:  이 |  이 you
# RM cyper ruff:  난 |  난 i
# Like A Star:  like |  어중간한 like
# 흔한 연습생의 크리스마스 (A Typical Trainee's Christmas):  to |  안 to
# Like A Star:  like |  어중간한 like
# Born Singer:  i'm |   i'm
# Hook 가요 (Free fall):  a |  훅가요 a
# Beautiful (Cover):  with |  해 me
# Graduation Song (졸업):  has |  nan has
# Adult Child (어른아이):  a |  된 a
# 7 Dayz:  uh |  날 uh
# Expensive Girl (비싼여자):  lights |  내 dim
# BTS - Born Singer (Romanized):  i'm |   i'm
# Thinking Bout U:  you |  넌 you
# 2009년 2번째 94년생 단체곡 (2009's Second 94-Liners Group Rap):  94 |  94 the
# 518-062:  go |  5-1-8 go
# Dream Money:  i |  삶을 i
# 싸이하누월 (It Doesn’t Matter) Mix Final:  click |  상관없어 click
# Swagger:  the |  난 the
# 학교의눈물 (School of Tears):  wrong |  방관자 wrong
# Seventeen:  the |  니가 the
# 필청 최고인듯 (Fuck Cockroachez):  to |  내 to
# 간지플레이어 (Kanji Player):  i |  난 i
# Can We [original title unknown]:  i |  이젠 i
# Diss:  you |  랩은 you
# Tipsy:  the |  난 the
# Freestyle:  there |  nan there
# We Are B.P.B:  the |  내 the
# Freestyle 3:  i |  난 i
# Freestyle 4:  to |  그 to
# Illest Bitch:  bitch |  nan bitch
# Vote (닥투):  the |  é the
# 녹음물 (Recording):  그 |  그 got
# Glory:  it |  난 it
# Trouble:  missing |  nan missing
# Freestyle 2:  i |  3 i
# Suicide:  you |  nan you
# Where U At:  at |  어디로 where
# La La La:  movin |  쉿 movin
# The Swagger:  yeah~ |  따라해 yeah~
# Naa:  to |  [] to
# Dreamin':  the |  있어 the
# Wicked Man:  the |  난 the
# The Realest:  넌 |  내 yo
# Favorite Girl:  favorite |   favorite
# We Are Bulletproof Pt. 1 (4 BEGINS Ruff):  we |  내 we
# Check the voice:  the |  난 the
# 일단 둘어봐 (Listen First):  i |  모두들 i
# Regular Girl:  a |  [] a
# Waterfalls (Cover):  waterfalls |  있을까 waterfalls
# Let's Introduce BANGTAN ROOM:  the |  19 the
# Danger (Mo-Blue-Mix):  너 |  너 it
# Tokyo:  i |  nan i
# Seoul:  you |  같은 you
# Moonchild:  you |  서로의 you
# Badbye:  me |  내줘 me
# 어긋 (uhgood):  i |  네게 i
# 지나가 (everythingoes):  everything |  지나가 everything
# Forever Rain:  rain |  영원히 rain
# 저 달 (Moonlight):  여전히 |  여전히 okay
# 대취타 (Daechwita):  대취타 |  대취타 yeah
# 어떻게 생각해? (What do you think?):  어떻게 |  어떻게 woo
# 이상하지 않은가 (Strange):  well |  자 well
# 점점 어른이 되나봐 (28):  게 |  게 shit
# Burn It:  yeah |  소리 yeah
# 사람 (People):  뭐 |  뭐 so
# 혼술 (Honsool):  i'm |  뭐 i'm
# Interlude: Set me free:  free |  내 free
# 어땠을까 (Dear my friend):  아직도 |  아직도 friend

# %%
print(genius_data["Most Common Word"].value_counts())
# Out:
# i          53
# you        35
# the        24
# la         16
#            15
#            ..
# 랩몬스터        1
# sunday      1
# monster     1
# base        1
# has         1
# Name: Most Common Word, Length: 174, dtype: int64
